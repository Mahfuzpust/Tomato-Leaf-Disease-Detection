# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahfuzpust/Tomato-Leaf-Disease-Detection/blob/main/Tomato_Leaf_Disease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# ! unzip -q "/content/drive/MyDrive/Tomato/tomato.zip"

# %% [markdown]
# # Import Libraries

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
tf.random.set_seed(42)

# %% [markdown]
# # Image path

# %%
train_dir = "/content/drive/MyDrive/tomato/train"
test_dir = "/content/drive/MyDrive/tomato/val"

# # Kaggle
# train_dir = "../input/tomatoleaf/tomato/train"
# test_dir = "../input/tomatoleaf/tomato/val"

# %% [markdown]
# # Data Rescaling and augmentation

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal",
    input_shape=(112, 112, 3)),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
  tf.keras.layers.experimental.preprocessing.RandomZoom(0.2),
  tf.keras.layers.experimental.preprocessing.RandomHeight(0.2),
  tf.keras.layers.experimental.preprocessing.RandomWidth(0.2),
  tf.keras.layers.experimental.preprocessing.Rescaling(1./255)
], name ="data_augmentation")

# %% [markdown]
# ## Load datasets (Shuffle and prefetch)

# %%
import tensorflow as tf

IMG_SIZE = (112, 112)
BATCH_SIZE = 32
train_data = tf.keras.preprocessing.image_dataset_from_directory(
    directory = train_dir,
    image_size = IMG_SIZE,
    label_mode = 'categorical',
    batch_size = BATCH_SIZE,
    shuffle = True,
    seed=42
).cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

test_data = tf.keras.preprocessing.image_dataset_from_directory(
    directory = test_dir,
    image_size = IMG_SIZE,
    label_mode = 'categorical',
    batch_size = BATCH_SIZE
)

class_names = test_data.class_names
valid_data = test_data.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# Found 10000 files belonging to 10 classes.
# Found 1000 files belonging to 10 classes.

# %% [markdown]
# # Visualize images

# %%
plt.figure(figsize=(18,10))
for image_batch,label_batch in train_data.take(1):
    for i in range(0,12):
        plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint32"))
        plt.title(class_names[np.argmax(label_batch[i])])
        plt.axis("off")

# %% [markdown]
# # Augmented image view

# %%
plt.figure(figsize=(10,10))
for image_batch,label_batch in train_data.take(1):
    augmented_image_batch = data_augmentation(image_batch)
    image_plt_len = len(image_batch) if len(image_batch) < 4 else 4
    for i in range(0, image_plt_len):
        plt.subplot(image_plt_len,2,2*i+1)
        plt.imshow(image_batch[i].numpy().astype("uint32"))
        plt.title(class_names[np.argmax(label_batch[i])])
        plt.axis("off")
        plt.subplot(image_plt_len,2,2*i+2)
        plt.imshow(augmented_image_batch[i])
        plt.title(f"augmented")
        plt.axis("off")

# %% [markdown]
# # Create Checkpoint

# %%
checkpoint_path = "CheckPoint/cp.ckpt"
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_path,
    save_weights_only=True,
    monitor='val_accuracy',
    save_best_only=True
)

# %% [markdown]
# ## Create model

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    data_augmentation,
    tf.keras.layers.Conv2D(32, 3, activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Conv2D(16, 3, activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Conv2D(32, 3, activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(len(class_names), activation='softmax', name='output_layers')

])

# %% [markdown]
# ## Summary model

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  data_augmentation (Sequent  (None, None, None, 3)     0
#  ial)
#
#  conv2d (Conv2D)             (None, None, None, 32)    896
#
#  max_pooling2d (MaxPooling2  (None, None, None, 32)    0
#  D)
#
#  conv2d_1 (Conv2D)           (None, None, None, 16)    4624
#
#  max_pooling2d_1 (MaxPoolin  (None, None, None, 16)    0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, None, None, 32)    4640
#
#  max_pooling2d_2 (MaxPoolin  (None, None, None, 32)    0
#  g2D)
#
#  global_average_pooling2d (  (None, 32)                0
#  GlobalAveragePooling2D)
#
#  output_layers (Dense)       (None, 10)                330
#
# =================================================================
# Total params: 10490 (40.98 KB)
# Trainable params: 10490 (40.98 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    #data_augmentation,
    tf.keras.layers.Conv2D(32, 3, activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Conv2D(16, 3, activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Conv2D(32, 3, activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(10, activation='softmax', name='output_layers')

])


model.build (input_shape=(32,112,112,3))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (32, 110, 110, 32)        896
#
#  max_pooling2d_3 (MaxPoolin  (32, 55, 55, 32)          0
#  g2D)
#
#  conv2d_4 (Conv2D)           (32, 53, 53, 16)          4624
#
#  max_pooling2d_4 (MaxPoolin  (32, 26, 26, 16)          0
#  g2D)
#
#  conv2d_5 (Conv2D)           (32, 24, 24, 32)          4640
#
#  max_pooling2d_5 (MaxPoolin  (32, 12, 12, 32)          0
#  g2D)
#
#  global_average_pooling2d_1  (32, 32)                  0
#   (GlobalAveragePooling2D)
#
#  output_layers (Dense)       (32, 10)                  330
#
# =================================================================
# Total params: 10490 (40.98 KB)
# Trainable params: 10490 (40.98 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Compile model

# %%
model.compile(
    loss = 'categorical_crossentropy',
    optimizer = tf.keras.optimizers.Adam(),
    metrics = ['accuracy']
)

# %% [markdown]
# ## Fit the model

# %%
history = model.fit(
    train_data,
    epochs=300,
    steps_per_epoch=len(train_data),
    validation_data = test_data,
    validation_steps = len(test_data),
    callbacks = [
        checkpoint_callback
    ]
)
# Out:
# Epoch 1/300
# 313/313 [==============================] - 132s 393ms/step - loss: 2.7148 - accuracy: 0.2485 - val_loss: 1.6437 - val_accuracy: 0.4130
# Epoch 2/300
# 313/313 [==============================] - 6s 18ms/step - loss: 1.4220 - accuracy: 0.4849 - val_loss: 1.1777 - val_accuracy: 0.5960
# Epoch 3/300
# 313/313 [==============================] - 4s 14ms/step - loss: 1.0407 - accuracy: 0.6293 - val_loss: 0.9248 - val_accuracy: 0.6570
# Epoch 4/300
# 313/313 [==============================] - 5s 17ms/step - loss: 0.8167 - accuracy: 0.7149 - val_loss: 0.9548 - val_accuracy: 0.6940
# Epoch 5/300
# 313/313 [==============================] - 6s 19ms/step - loss: 0.7238 - accuracy: 0.7497 - val_loss: 0.7674 - val_accuracy: 0.7310
# Epoch 6/300
# 313/313 [==============================] - 5s 15ms/step - loss: 0.6383 - accuracy: 0.7780 - val_loss: 0.6713 - val_accuracy: 0.7830
# Epoch 7/300
# 313/313 [==============================] - 6s 19ms/step - loss: 0.5775 - accuracy: 0.7979 - val_loss: 0.5872 - val_accuracy: 0.8160
# Epoch 8/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.5150 - accuracy: 0.8238 - val_loss: 0.6310 - val_accuracy: 0.7820
# Epoch 9/300
# 313/313 [==============================] - 5s 17ms/step - loss: 0.4983 - accuracy: 0.8286 - val_loss: 0.5127 - val_accuracy: 0.8370
# Epoch 10/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.4452 - accuracy: 0.8482 - val_loss: 0.4736 - val_accuracy: 0.8360
# Epoch 11/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.4473 - accuracy: 0.8443 - val_loss: 0.4856 - val_accuracy: 0.8290
# Epoch 12/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.4175 - accuracy: 0.8557 - val_loss: 0.5157 - val_accuracy: 0.8200
# Epoch 13/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.4064 - accuracy: 0.8597 - val_loss: 0.4108 - val_accuracy: 0.8590
# Epoch 14/300
# 313/313 [==============================] - 4s 13ms/step - loss: 0.3705 - accuracy: 0.8755 - val_loss: 0.4191 - val_accuracy: 0.8580
# Epoch 15/300
# 313/313 [==============================] - 5s 16ms/step - loss: 0.3694 - accuracy: 0.8726 - val_loss: 0.4296 - val_accuracy: 0.8490
# Epoch 16/300
# 313/313 [==============================] - 5s 15ms/step - loss: 0.3526 - accuracy: 0.8812 - val_loss: 0.4420 - val_accuracy: 0.8660
# Epoch 17/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3061 - accuracy: 0.8952 - val_loss: 0.4193 - val_accuracy: 0.8610
# Epoch 18/300
# 313/313 [==============================] - 5s 15ms/step - loss: 0.3076 - accuracy: 0.8955 - val_loss: 0.5196 - val_accuracy: 0.8320
# Epoch 19/300
# 313/313 [==============================] - 5s 15ms/step - loss: 0.2958 - accuracy: 0.9014 - val_loss: 0.3790 - val_accuracy: 0.8630
# Epoch 20/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.3037 - accuracy: 0.8979 - val_loss: 0.5938 - val_accuracy: 0.8090
# Epoch 21/300
# 313/313 [==============================] - 5s 17ms/step - loss: 0.2860 - accuracy: 0.9014 - val_loss: 0.3347 - val_accuracy: 0.8860
# Epoch 22/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.2656 - accuracy: 0.9082 - val_loss: 0.3608 - val_accuracy: 0.8570
# Epoch 23/300
# 313/313 [==============================] - 5s 17ms/step - loss: 0.2486 - accuracy: 0.9171 - val_loss: 0.3522 - val_accuracy: 0.8900
# Epoch 24/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.2440 - accuracy: 0.9169 - val_loss: 0.3803 - val_accuracy: 0.8800
# Epoch 25/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.2230 - accuracy: 0.9269 - val_loss: 0.3288 - val_accuracy: 0.8990
# Epoch 26/300
# 313/313 [==============================] - 5s 18ms/step - loss: 0.2270 - accuracy: 0.9235 - val_loss: 0.2848 - val_accuracy: 0.9010
# Epoch 27/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.2123 - accuracy: 0.9265 - val_loss: 0.3021 - val_accuracy: 0.9020
# Epoch 28/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.2159 - accuracy: 0.9272 - val_loss: 0.3664 - val_accuracy: 0.8910
# Epoch 29/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.1877 - accuracy: 0.9336 - val_loss: 0.2864 - val_accuracy: 0.9110
# Epoch 30/300
# 313/313 [==============================] - 5s 18ms/step - loss: 0.2032 - accuracy: 0.9302 - val_loss: 0.3880 - val_accuracy: 0.8910
# Epoch 31/300
# 313/313 [==============================] - 6s 19ms/step - loss: 0.1870 - accuracy: 0.9356 - val_loss: 0.2683 - val_accuracy: 0.9170
# Epoch 32/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.2016 - accuracy: 0.9309 - val_loss: 0.3323 - val_accuracy: 0.8980
# Epoch 33/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.1882 - accuracy: 0.9351 - val_loss: 0.3628 - val_accuracy: 0.8820
# Epoch 34/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.1580 - accuracy: 0.9445 - val_loss: 0.3243 - val_accuracy: 0.8920
# Epoch 35/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.1914 - accuracy: 0.9326 - val_loss: 0.3962 - val_accuracy: 0.8750
# Epoch 36/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.1712 - accuracy: 0.9404 - val_loss: 0.3545 - val_accuracy: 0.9060
# Epoch 37/300
# 313/313 [==============================] - 5s 17ms/step - loss: 0.1441 - accuracy: 0.9492 - val_loss: 0.3059 - val_accuracy: 0.8960
# Epoch 38/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.1471 - accuracy: 0.9473 - val_loss: 0.2486 - val_accuracy: 0.9170
# Epoch 39/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.1586 - accuracy: 0.9462 - val_loss: 0.2547 - val_accuracy: 0.9170
# Epoch 40/300
# 313/313 [==============================] - 6s 19ms/step - loss: 0.1362 - accuracy: 0.9512 - val_loss: 0.2524 - val_accuracy: 0.9160
# Epoch 41/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.1738 - accuracy: 0.9398 - val_loss: 0.5556 - val_accuracy: 0.8460
# Epoch 42/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.1319 - accuracy: 0.9569 - val_loss: 0.4337 - val_accuracy: 0.8980
# Epoch 43/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.1344 - accuracy: 0.9535 - val_loss: 0.2929 - val_accuracy: 0.9110
# Epoch 44/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.1195 - accuracy: 0.9607 - val_loss: 0.2715 - val_accuracy: 0.9190
# Epoch 45/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.1249 - accuracy: 0.9571 - val_loss: 0.3307 - val_accuracy: 0.9090
# Epoch 46/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.1179 - accuracy: 0.9608 - val_loss: 0.2990 - val_accuracy: 0.9050
# Epoch 47/300
# 313/313 [==============================] - 5s 17ms/step - loss: 0.1295 - accuracy: 0.9566 - val_loss: 0.3263 - val_accuracy: 0.9070
# Epoch 48/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.1349 - accuracy: 0.9544 - val_loss: 0.2549 - val_accuracy: 0.9230
# Epoch 49/300
# 313/313 [==============================] - 6s 19ms/step - loss: 0.1115 - accuracy: 0.9618 - val_loss: 0.2735 - val_accuracy: 0.9230
# Epoch 50/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.1103 - accuracy: 0.9614 - val_loss: 0.3654 - val_accuracy: 0.8970
# Epoch 51/300
# 313/313 [==============================] - 5s 17ms/step - loss: 0.1154 - accuracy: 0.9597 - val_loss: 0.2693 - val_accuracy: 0.9220
# Epoch 52/300
# 313/313 [==============================] - 5s 18ms/step - loss: 0.1059 - accuracy: 0.9632 - val_loss: 0.3497 - val_accuracy: 0.9170
# Epoch 53/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.1164 - accuracy: 0.9618 - val_loss: 0.2680 - val_accuracy: 0.9180
# Epoch 54/300
# 313/313 [==============================] - 5s 15ms/step - loss: 0.0999 - accuracy: 0.9660 - val_loss: 0.2700 - val_accuracy: 0.9210
# Epoch 55/300
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0958 - accuracy: 0.9650 - val_loss: 0.3542 - val_accuracy: 0.9060
# Epoch 56/300
# 313/313 [==============================] - 5s 17ms/step - loss: 0.1030 - accuracy: 0.9641 - val_loss: 0.2843 - val_accuracy: 0.9160
# Epoch 57/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0887 - accuracy: 0.9698 - val_loss: 0.2924 - val_accuracy: 0.9180
# Epoch 58/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0971 - accuracy: 0.9642 - val_loss: 0.3732 - val_accuracy: 0.9120
# Epoch 59/300
# 313/313 [==============================] - 5s 17ms/step - loss: 0.1192 - accuracy: 0.9596 - val_loss: 0.2547 - val_accuracy: 0.9340
# Epoch 60/300
# 313/313 [==============================] - 5s 18ms/step - loss: 0.0753 - accuracy: 0.9741 - val_loss: 0.3043 - val_accuracy: 0.9170
# Epoch 61/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0905 - accuracy: 0.9692 - val_loss: 0.4242 - val_accuracy: 0.8960
# Epoch 62/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.1009 - accuracy: 0.9637 - val_loss: 0.2423 - val_accuracy: 0.9330
# Epoch 63/300
# 313/313 [==============================] - 6s 19ms/step - loss: 0.0719 - accuracy: 0.9737 - val_loss: 0.3988 - val_accuracy: 0.9010
# Epoch 64/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0899 - accuracy: 0.9691 - val_loss: 0.2610 - val_accuracy: 0.9250
# Epoch 65/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0818 - accuracy: 0.9717 - val_loss: 0.2673 - val_accuracy: 0.9270
# Epoch 66/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.1074 - accuracy: 0.9662 - val_loss: 0.2267 - val_accuracy: 0.9290
# Epoch 67/300
# 313/313 [==============================] - 6s 19ms/step - loss: 0.0726 - accuracy: 0.9766 - val_loss: 0.3292 - val_accuracy: 0.9120
# Epoch 68/300
# 313/313 [==============================] - 5s 15ms/step - loss: 0.0800 - accuracy: 0.9729 - val_loss: 0.2966 - val_accuracy: 0.9170
# Epoch 69/300
# 313/313 [==============================] - 5s 17ms/step - loss: 0.0620 - accuracy: 0.9788 - val_loss: 0.2821 - val_accuracy: 0.9290
# Epoch 70/300
# 313/313 [==============================] - 5s 15ms/step - loss: 0.0832 - accuracy: 0.9705 - val_loss: 0.3065 - val_accuracy: 0.9100
# Epoch 71/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0575 - accuracy: 0.9812 - val_loss: 0.3608 - val_accuracy: 0.9090
# Epoch 72/300
# 313/313 [==============================] - 5s 17ms/step - loss: 0.0757 - accuracy: 0.9727 - val_loss: 0.2368 - val_accuracy: 0.9360
# Epoch 73/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0972 - accuracy: 0.9668 - val_loss: 0.2731 - val_accuracy: 0.9300
# Epoch 74/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0721 - accuracy: 0.9757 - val_loss: 0.3182 - val_accuracy: 0.9240
# Epoch 75/300
# 313/313 [==============================] - 5s 15ms/step - loss: 0.0670 - accuracy: 0.9771 - val_loss: 0.3413 - val_accuracy: 0.9070
# Epoch 76/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0717 - accuracy: 0.9776 - val_loss: 0.3097 - val_accuracy: 0.9200
# Epoch 77/300
# 313/313 [==============================] - 5s 15ms/step - loss: 0.0498 - accuracy: 0.9828 - val_loss: 0.2859 - val_accuracy: 0.9290
# Epoch 78/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0475 - accuracy: 0.9838 - val_loss: 0.2745 - val_accuracy: 0.9230
# Epoch 79/300
# 313/313 [==============================] - 5s 17ms/step - loss: 0.0886 - accuracy: 0.9704 - val_loss: 0.3356 - val_accuracy: 0.9120
# Epoch 80/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0812 - accuracy: 0.9715 - val_loss: 0.6303 - val_accuracy: 0.8640
# Epoch 81/300
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0632 - accuracy: 0.9800 - val_loss: 0.2462 - val_accuracy: 0.9350
# Epoch 82/300
# 313/313 [==============================] - 6s 19ms/step - loss: 0.0666 - accuracy: 0.9790 - val_loss: 0.2708 - val_accuracy: 0.9270
# Epoch 83/300
# 313/313 [==============================] - 5s 14ms/step - loss: 0.0567 - accuracy: 0.9805 - val_loss: 0.2758 - val_accuracy: 0.9270
# Epoch 84/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0388 - accuracy: 0.9872 - val_loss: 0.3921 - val_accuracy: 0.8990
# Epoch 85/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0580 - accuracy: 0.9813 - val_loss: 0.2280 - val_accuracy: 0.9330
# Epoch 86/300
# 313/313 [==============================] - 5s 15ms/step - loss: 0.0894 - accuracy: 0.9705 - val_loss: 0.3546 - val_accuracy: 0.9310
# Epoch 87/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0471 - accuracy: 0.9847 - val_loss: 0.3490 - val_accuracy: 0.9250
# Epoch 88/300
# 313/313 [==============================] - 5s 17ms/step - loss: 0.0530 - accuracy: 0.9827 - val_loss: 0.3138 - val_accuracy: 0.9260
# Epoch 89/300
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0618 - accuracy: 0.9798 - val_loss: 0.2878 - val_accuracy: 0.9270
# Epoch 90/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0588 - accuracy: 0.9800 - val_loss: 0.4457 - val_accuracy: 0.9060
# Epoch 91/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0407 - accuracy: 0.9861 - val_loss: 0.3376 - val_accuracy: 0.9220
# Epoch 92/300
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0772 - accuracy: 0.9727 - val_loss: 0.3757 - val_accuracy: 0.9060
# Epoch 93/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0457 - accuracy: 0.9846 - val_loss: 0.3432 - val_accuracy: 0.9230
# Epoch 94/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0662 - accuracy: 0.9795 - val_loss: 0.3461 - val_accuracy: 0.9290
# Epoch 95/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0749 - accuracy: 0.9754 - val_loss: 0.2984 - val_accuracy: 0.9230
# Epoch 96/300
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0464 - accuracy: 0.9844 - val_loss: 0.2626 - val_accuracy: 0.9340
# Epoch 97/300
# 313/313 [==============================] - 5s 17ms/step - loss: 0.0312 - accuracy: 0.9886 - val_loss: 0.3896 - val_accuracy: 0.9070
# Epoch 98/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0774 - accuracy: 0.9740 - val_loss: 0.6650 - val_accuracy: 0.8650
# Epoch 99/300
# 313/313 [==============================] - 5s 17ms/step - loss: 0.0582 - accuracy: 0.9804 - val_loss: 0.2933 - val_accuracy: 0.9330
# Epoch 100/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0379 - accuracy: 0.9869 - val_loss: 0.2775 - val_accuracy: 0.9330
# Epoch 101/300
# 313/313 [==============================] - 6s 19ms/step - loss: 0.0552 - accuracy: 0.9833 - val_loss: 0.2820 - val_accuracy: 0.9280
# Epoch 102/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0529 - accuracy: 0.9846 - val_loss: 0.2928 - val_accuracy: 0.9330
# Epoch 103/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0140 - accuracy: 0.9969 - val_loss: 0.2628 - val_accuracy: 0.9440
# Epoch 104/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0611 - accuracy: 0.9822 - val_loss: 0.4549 - val_accuracy: 0.9060
# Epoch 105/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0777 - accuracy: 0.9742 - val_loss: 0.3568 - val_accuracy: 0.9000
# Epoch 106/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0248 - accuracy: 0.9921 - val_loss: 0.2729 - val_accuracy: 0.9430
# Epoch 107/300
# 313/313 [==============================] - 5s 17ms/step - loss: 0.0663 - accuracy: 0.9795 - val_loss: 0.3423 - val_accuracy: 0.9310
# Epoch 108/300
# 313/313 [==============================] - 6s 19ms/step - loss: 0.0384 - accuracy: 0.9870 - val_loss: 0.6558 - val_accuracy: 0.8620
# Epoch 109/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0343 - accuracy: 0.9877 - val_loss: 0.3242 - val_accuracy: 0.9280
# Epoch 110/300
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0548 - accuracy: 0.9802 - val_loss: 0.4460 - val_accuracy: 0.9000
# Epoch 111/300
# 313/313 [==============================] - 5s 15ms/step - loss: 0.0443 - accuracy: 0.9851 - val_loss: 0.2795 - val_accuracy: 0.9400
# Epoch 112/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0115 - accuracy: 0.9970 - val_loss: 0.2598 - val_accuracy: 0.9430
# Epoch 113/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0255 - accuracy: 0.9916 - val_loss: 0.3436 - val_accuracy: 0.9240
# Epoch 114/300
# 313/313 [==============================] - 5s 17ms/step - loss: 0.0997 - accuracy: 0.9699 - val_loss: 0.4906 - val_accuracy: 0.9020
# Epoch 115/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0745 - accuracy: 0.9733 - val_loss: 0.3660 - val_accuracy: 0.9310
# Epoch 116/300
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0154 - accuracy: 0.9955 - val_loss: 0.2682 - val_accuracy: 0.9400
# Epoch 117/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0216 - accuracy: 0.9930 - val_loss: 0.2864 - val_accuracy: 0.9400
# Epoch 118/300
# 313/313 [==============================] - 6s 19ms/step - loss: 0.0405 - accuracy: 0.9872 - val_loss: 0.3220 - val_accuracy: 0.9340
# Epoch 119/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0425 - accuracy: 0.9845 - val_loss: 0.7338 - val_accuracy: 0.8720
# Epoch 120/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0628 - accuracy: 0.9776 - val_loss: 0.3633 - val_accuracy: 0.9170
# Epoch 121/300
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0181 - accuracy: 0.9942 - val_loss: 0.3138 - val_accuracy: 0.9300
# Epoch 122/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0241 - accuracy: 0.9920 - val_loss: 0.3204 - val_accuracy: 0.9330
# Epoch 123/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0771 - accuracy: 0.9755 - val_loss: 0.5007 - val_accuracy: 0.9060
# Epoch 124/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0343 - accuracy: 0.9888 - val_loss: 0.3272 - val_accuracy: 0.9430
# Epoch 125/300
# 313/313 [==============================] - 6s 19ms/step - loss: 0.0635 - accuracy: 0.9815 - val_loss: 0.4291 - val_accuracy: 0.9240
# Epoch 126/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0400 - accuracy: 0.9866 - val_loss: 0.3287 - val_accuracy: 0.9300
# Epoch 127/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0175 - accuracy: 0.9944 - val_loss: 0.3362 - val_accuracy: 0.9350
# Epoch 128/300
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0071 - accuracy: 0.9987 - val_loss: 0.3084 - val_accuracy: 0.9400
# Epoch 129/300
# 313/313 [==============================] - 5s 15ms/step - loss: 0.0409 - accuracy: 0.9877 - val_loss: 0.4952 - val_accuracy: 0.9150
# Epoch 130/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0889 - accuracy: 0.9721 - val_loss: 0.3441 - val_accuracy: 0.9290
# Epoch 131/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0208 - accuracy: 0.9931 - val_loss: 0.2700 - val_accuracy: 0.9380
# Epoch 132/300
# 313/313 [==============================] - 5s 15ms/step - loss: 0.0107 - accuracy: 0.9969 - val_loss: 0.3778 - val_accuracy: 0.9270
# Epoch 133/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0810 - accuracy: 0.9718 - val_loss: 0.5610 - val_accuracy: 0.9040
# Epoch 134/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0257 - accuracy: 0.9909 - val_loss: 0.3134 - val_accuracy: 0.9420
# Epoch 135/300
# 313/313 [==============================] - 5s 17ms/step - loss: 0.0086 - accuracy: 0.9980 - val_loss: 0.3130 - val_accuracy: 0.9410
# Epoch 136/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0370 - accuracy: 0.9891 - val_loss: 0.4234 - val_accuracy: 0.8950
# Epoch 137/300
# 313/313 [==============================] - 6s 19ms/step - loss: 0.0519 - accuracy: 0.9812 - val_loss: 0.5030 - val_accuracy: 0.9100
# Epoch 138/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0692 - accuracy: 0.9788 - val_loss: 0.3740 - val_accuracy: 0.9280
# Epoch 139/300
# 313/313 [==============================] - 6s 19ms/step - loss: 0.0082 - accuracy: 0.9977 - val_loss: 0.3041 - val_accuracy: 0.9400
# Epoch 140/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0052 - accuracy: 0.9991 - val_loss: 0.2997 - val_accuracy: 0.9420
# Epoch 141/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0182 - accuracy: 0.9949 - val_loss: 0.6213 - val_accuracy: 0.8970
# Epoch 142/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0841 - accuracy: 0.9743 - val_loss: 0.4383 - val_accuracy: 0.8950
# Epoch 143/300
# 313/313 [==============================] - 5s 17ms/step - loss: 0.0756 - accuracy: 0.9772 - val_loss: 0.3162 - val_accuracy: 0.9430
# Epoch 144/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0080 - accuracy: 0.9981 - val_loss: 0.3137 - val_accuracy: 0.9360
# Epoch 145/300
# 313/313 [==============================] - 6s 19ms/step - loss: 0.0046 - accuracy: 0.9995 - val_loss: 0.3546 - val_accuracy: 0.9360
# Epoch 146/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0542 - accuracy: 0.9824 - val_loss: 0.4336 - val_accuracy: 0.9110
# Epoch 147/300
# 313/313 [==============================] - 5s 17ms/step - loss: 0.0293 - accuracy: 0.9902 - val_loss: 0.3939 - val_accuracy: 0.9120
# Epoch 148/300
# 313/313 [==============================] - 5s 15ms/step - loss: 0.0302 - accuracy: 0.9883 - val_loss: 0.4215 - val_accuracy: 0.9230
# Epoch 149/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0343 - accuracy: 0.9885 - val_loss: 0.3746 - val_accuracy: 0.9390
# Epoch 150/300
# 313/313 [==============================] - 6s 19ms/step - loss: 0.0533 - accuracy: 0.9822 - val_loss: 0.3596 - val_accuracy: 0.9290
# Epoch 151/300
# 313/313 [==============================] - 5s 14ms/step - loss: 0.0109 - accuracy: 0.9969 - val_loss: 0.3250 - val_accuracy: 0.9380
# Epoch 152/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0029 - accuracy: 0.9995 - val_loss: 0.3139 - val_accuracy: 0.9420
# Epoch 153/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0018 - accuracy: 0.9998 - val_loss: 0.3246 - val_accuracy: 0.9420
# Epoch 154/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.3462 - val_accuracy: 0.9350
# Epoch 155/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.1114 - accuracy: 0.9699 - val_loss: 0.3706 - val_accuracy: 0.9260
# Epoch 156/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0165 - accuracy: 0.9948 - val_loss: 0.4053 - val_accuracy: 0.9210
# Epoch 157/300
# 313/313 [==============================] - 5s 17ms/step - loss: 0.0050 - accuracy: 0.9989 - val_loss: 0.3424 - val_accuracy: 0.9420
# Epoch 158/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0655 - accuracy: 0.9794 - val_loss: 0.5045 - val_accuracy: 0.9040
# Epoch 159/300
# 313/313 [==============================] - 5s 17ms/step - loss: 0.0427 - accuracy: 0.9873 - val_loss: 0.3619 - val_accuracy: 0.9320
# Epoch 160/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0074 - accuracy: 0.9975 - val_loss: 0.3983 - val_accuracy: 0.9290
# Epoch 161/300
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0063 - accuracy: 0.9985 - val_loss: 0.4225 - val_accuracy: 0.9350
# Epoch 162/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0774 - accuracy: 0.9768 - val_loss: 0.3805 - val_accuracy: 0.9240
# Epoch 163/300
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0100 - accuracy: 0.9970 - val_loss: 0.3415 - val_accuracy: 0.9410
# Epoch 164/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0496 - accuracy: 0.9863 - val_loss: 0.3798 - val_accuracy: 0.9300
# Epoch 165/300
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0269 - accuracy: 0.9902 - val_loss: 0.3209 - val_accuracy: 0.9370
# Epoch 166/300
# 313/313 [==============================] - 5s 15ms/step - loss: 0.0230 - accuracy: 0.9929 - val_loss: 0.4635 - val_accuracy: 0.9160
# Epoch 167/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0841 - accuracy: 0.9747 - val_loss: 0.3544 - val_accuracy: 0.9290
# Epoch 168/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0111 - accuracy: 0.9961 - val_loss: 0.2744 - val_accuracy: 0.9480
# Epoch 169/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.2943 - val_accuracy: 0.9400
# Epoch 170/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.3346 - val_accuracy: 0.9440
# Epoch 171/300
# 313/313 [==============================] - 5s 15ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.2962 - val_accuracy: 0.9490
# Epoch 172/300
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0017 - accuracy: 0.9998 - val_loss: 0.3259 - val_accuracy: 0.9410
# Epoch 173/300
# 313/313 [==============================] - 5s 15ms/step - loss: 0.0015 - accuracy: 0.9999 - val_loss: 0.3385 - val_accuracy: 0.9440
# Epoch 174/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.1047 - accuracy: 0.9744 - val_loss: 0.4710 - val_accuracy: 0.9030
# Epoch 175/300
# 313/313 [==============================] - 5s 15ms/step - loss: 0.0419 - accuracy: 0.9857 - val_loss: 0.3293 - val_accuracy: 0.9380
# Epoch 176/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0143 - accuracy: 0.9956 - val_loss: 0.3647 - val_accuracy: 0.9250
# Epoch 177/300
# 313/313 [==============================] - 5s 15ms/step - loss: 0.0213 - accuracy: 0.9941 - val_loss: 0.3280 - val_accuracy: 0.9460
# Epoch 178/300
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0101 - accuracy: 0.9973 - val_loss: 0.3706 - val_accuracy: 0.9360
# Epoch 179/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0953 - accuracy: 0.9742 - val_loss: 0.5221 - val_accuracy: 0.9040
# Epoch 180/300
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0152 - accuracy: 0.9954 - val_loss: 0.3845 - val_accuracy: 0.9370
# Epoch 181/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.3479 - val_accuracy: 0.9400
# Epoch 182/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0014 - accuracy: 0.9999 - val_loss: 0.3189 - val_accuracy: 0.9470
# Epoch 183/300
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.3310 - val_accuracy: 0.9430
# Epoch 184/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.3438 - val_accuracy: 0.9420
# Epoch 185/300
# 313/313 [==============================] - 4s 14ms/step - loss: 9.6053e-04 - accuracy: 0.9997 - val_loss: 0.3342 - val_accuracy: 0.9500
# Epoch 186/300
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1137 - accuracy: 0.9697 - val_loss: 0.6536 - val_accuracy: 0.8970
# Epoch 187/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0637 - accuracy: 0.9803 - val_loss: 0.3158 - val_accuracy: 0.9390
# Epoch 188/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0053 - accuracy: 0.9987 - val_loss: 0.3279 - val_accuracy: 0.9430
# Epoch 189/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0024 - accuracy: 0.9998 - val_loss: 0.3053 - val_accuracy: 0.9440
# Epoch 190/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.3165 - val_accuracy: 0.9460
# Epoch 191/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.3071 - val_accuracy: 0.9420
# Epoch 192/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0017 - accuracy: 0.9998 - val_loss: 0.3132 - val_accuracy: 0.9420
# Epoch 193/300
# 313/313 [==============================] - 5s 18ms/step - loss: 8.8414e-04 - accuracy: 1.0000 - val_loss: 0.3070 - val_accuracy: 0.9450
# Epoch 194/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.1177 - accuracy: 0.9746 - val_loss: 0.5064 - val_accuracy: 0.9080
# Epoch 195/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0493 - accuracy: 0.9840 - val_loss: 0.3766 - val_accuracy: 0.9230
# Epoch 196/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0058 - accuracy: 0.9987 - val_loss: 0.3545 - val_accuracy: 0.9350
# Epoch 197/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2982 - val_accuracy: 0.9480
# Epoch 198/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3182 - val_accuracy: 0.9470
# Epoch 199/300
# 313/313 [==============================] - 6s 18ms/step - loss: 9.2493e-04 - accuracy: 1.0000 - val_loss: 0.3226 - val_accuracy: 0.9470
# Epoch 200/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.3438 - val_accuracy: 0.9460
# Epoch 201/300
# 313/313 [==============================] - 5s 16ms/step - loss: 0.1128 - accuracy: 0.9743 - val_loss: 0.4972 - val_accuracy: 0.8980
# Epoch 202/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0350 - accuracy: 0.9892 - val_loss: 0.3215 - val_accuracy: 0.9310
# Epoch 203/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0250 - accuracy: 0.9917 - val_loss: 0.3503 - val_accuracy: 0.9240
# Epoch 204/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0065 - accuracy: 0.9981 - val_loss: 0.3459 - val_accuracy: 0.9350
# Epoch 205/300
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0231 - accuracy: 0.9925 - val_loss: 0.5246 - val_accuracy: 0.9260
# Epoch 206/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0730 - accuracy: 0.9795 - val_loss: 0.4073 - val_accuracy: 0.9230
# Epoch 207/300
# 313/313 [==============================] - 4s 13ms/step - loss: 0.0206 - accuracy: 0.9928 - val_loss: 0.3265 - val_accuracy: 0.9400
# Epoch 208/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0099 - accuracy: 0.9965 - val_loss: 0.3466 - val_accuracy: 0.9380
# Epoch 209/300
# 313/313 [==============================] - 6s 19ms/step - loss: 0.0236 - accuracy: 0.9914 - val_loss: 0.4477 - val_accuracy: 0.9140
# Epoch 210/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0591 - accuracy: 0.9808 - val_loss: 0.4484 - val_accuracy: 0.9180
# Epoch 211/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0194 - accuracy: 0.9929 - val_loss: 0.3207 - val_accuracy: 0.9420
# Epoch 212/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0029 - accuracy: 0.9993 - val_loss: 0.3367 - val_accuracy: 0.9410
# Epoch 213/300
# 313/313 [==============================] - 4s 14ms/step - loss: 9.6282e-04 - accuracy: 0.9999 - val_loss: 0.3071 - val_accuracy: 0.9480
# Epoch 214/300
# 313/313 [==============================] - 4s 14ms/step - loss: 8.1841e-04 - accuracy: 0.9999 - val_loss: 0.3159 - val_accuracy: 0.9450
# Epoch 215/300
# 313/313 [==============================] - 5s 18ms/step - loss: 5.2391e-04 - accuracy: 1.0000 - val_loss: 0.3061 - val_accuracy: 0.9480
# Epoch 216/300
# 313/313 [==============================] - 5s 15ms/step - loss: 4.8308e-04 - accuracy: 1.0000 - val_loss: 0.3064 - val_accuracy: 0.9490
# Epoch 217/300
# 313/313 [==============================] - 6s 18ms/step - loss: 4.3716e-04 - accuracy: 1.0000 - val_loss: 0.3135 - val_accuracy: 0.9470
# Epoch 218/300
# 313/313 [==============================] - 5s 15ms/step - loss: 4.7653e-04 - accuracy: 1.0000 - val_loss: 0.3245 - val_accuracy: 0.9410
# Epoch 219/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.1820 - accuracy: 0.9600 - val_loss: 0.3388 - val_accuracy: 0.9240
# Epoch 220/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0167 - accuracy: 0.9949 - val_loss: 0.3354 - val_accuracy: 0.9380
# Epoch 221/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0027 - accuracy: 0.9999 - val_loss: 0.3562 - val_accuracy: 0.9440
# Epoch 222/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3213 - val_accuracy: 0.9400
# Epoch 223/300
# 313/313 [==============================] - 4s 14ms/step - loss: 9.9370e-04 - accuracy: 1.0000 - val_loss: 0.3243 - val_accuracy: 0.9460
# Epoch 224/300
# 313/313 [==============================] - 5s 16ms/step - loss: 8.6435e-04 - accuracy: 1.0000 - val_loss: 0.3259 - val_accuracy: 0.9430
# Epoch 225/300
# 313/313 [==============================] - 4s 14ms/step - loss: 7.6383e-04 - accuracy: 1.0000 - val_loss: 0.3362 - val_accuracy: 0.9420
# Epoch 226/300
# 313/313 [==============================] - 4s 14ms/step - loss: 6.6328e-04 - accuracy: 1.0000 - val_loss: 0.3497 - val_accuracy: 0.9450
# Epoch 227/300
# 313/313 [==============================] - 6s 18ms/step - loss: 6.2207e-04 - accuracy: 1.0000 - val_loss: 0.3315 - val_accuracy: 0.9440
# Epoch 228/300
# 313/313 [==============================] - 4s 14ms/step - loss: 5.7324e-04 - accuracy: 1.0000 - val_loss: 0.3340 - val_accuracy: 0.9450
# Epoch 229/300
# 313/313 [==============================] - 5s 16ms/step - loss: 4.1059e-04 - accuracy: 1.0000 - val_loss: 0.3761 - val_accuracy: 0.9410
# Epoch 230/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0843 - accuracy: 0.9855 - val_loss: 0.9128 - val_accuracy: 0.8460
# Epoch 231/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.1050 - accuracy: 0.9735 - val_loss: 0.6562 - val_accuracy: 0.9090
# Epoch 232/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0163 - accuracy: 0.9944 - val_loss: 0.3176 - val_accuracy: 0.9400
# Epoch 233/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0019 - accuracy: 0.9999 - val_loss: 0.3228 - val_accuracy: 0.9410
# Epoch 234/300
# 313/313 [==============================] - 4s 14ms/step - loss: 8.3805e-04 - accuracy: 1.0000 - val_loss: 0.3226 - val_accuracy: 0.9440
# Epoch 235/300
# 313/313 [==============================] - 6s 18ms/step - loss: 6.8129e-04 - accuracy: 1.0000 - val_loss: 0.3175 - val_accuracy: 0.9430
# Epoch 236/300
# 313/313 [==============================] - 6s 18ms/step - loss: 5.4147e-04 - accuracy: 1.0000 - val_loss: 0.3227 - val_accuracy: 0.9420
# Epoch 237/300
# 313/313 [==============================] - 6s 18ms/step - loss: 4.8229e-04 - accuracy: 1.0000 - val_loss: 0.3216 - val_accuracy: 0.9450
# Epoch 238/300
# 313/313 [==============================] - 4s 14ms/step - loss: 4.5927e-04 - accuracy: 1.0000 - val_loss: 0.3217 - val_accuracy: 0.9440
# Epoch 239/300
# 313/313 [==============================] - 6s 18ms/step - loss: 4.0839e-04 - accuracy: 1.0000 - val_loss: 0.3294 - val_accuracy: 0.9470
# Epoch 240/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0291 - accuracy: 0.9957 - val_loss: 1.3153 - val_accuracy: 0.8180
# Epoch 241/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.1779 - accuracy: 0.9593 - val_loss: 0.3303 - val_accuracy: 0.9360
# Epoch 242/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0089 - accuracy: 0.9979 - val_loss: 0.2995 - val_accuracy: 0.9460
# Epoch 243/300
# 313/313 [==============================] - 5s 18ms/step - loss: 0.0029 - accuracy: 0.9996 - val_loss: 0.3314 - val_accuracy: 0.9430
# Epoch 244/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3141 - val_accuracy: 0.9430
# Epoch 245/300
# 313/313 [==============================] - 4s 14ms/step - loss: 9.3581e-04 - accuracy: 1.0000 - val_loss: 0.3228 - val_accuracy: 0.9450
# Epoch 246/300
# 313/313 [==============================] - 6s 18ms/step - loss: 8.3852e-04 - accuracy: 1.0000 - val_loss: 0.3210 - val_accuracy: 0.9450
# Epoch 247/300
# 313/313 [==============================] - 4s 13ms/step - loss: 7.1748e-04 - accuracy: 1.0000 - val_loss: 0.3254 - val_accuracy: 0.9460
# Epoch 248/300
# 313/313 [==============================] - 6s 18ms/step - loss: 6.3780e-04 - accuracy: 1.0000 - val_loss: 0.3653 - val_accuracy: 0.9420
# Epoch 249/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.1754 - accuracy: 0.9588 - val_loss: 0.4828 - val_accuracy: 0.9110
# Epoch 250/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0350 - accuracy: 0.9890 - val_loss: 0.4481 - val_accuracy: 0.9280
# Epoch 251/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0287 - accuracy: 0.9905 - val_loss: 0.3342 - val_accuracy: 0.9370
# Epoch 252/300
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0032 - accuracy: 0.9996 - val_loss: 0.3040 - val_accuracy: 0.9410
# Epoch 253/300
# 313/313 [==============================] - 5s 14ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.3154 - val_accuracy: 0.9450
# Epoch 254/300
# 313/313 [==============================] - 6s 18ms/step - loss: 9.3779e-04 - accuracy: 1.0000 - val_loss: 0.3141 - val_accuracy: 0.9450
# Epoch 255/300
# 313/313 [==============================] - 5s 14ms/step - loss: 7.2641e-04 - accuracy: 1.0000 - val_loss: 0.3173 - val_accuracy: 0.9420
# Epoch 256/300
# 313/313 [==============================] - 4s 14ms/step - loss: 6.2592e-04 - accuracy: 1.0000 - val_loss: 0.3177 - val_accuracy: 0.9420
# Epoch 257/300
# 313/313 [==============================] - 6s 18ms/step - loss: 5.9854e-04 - accuracy: 1.0000 - val_loss: 0.3152 - val_accuracy: 0.9420
# Epoch 258/300
# 313/313 [==============================] - 6s 18ms/step - loss: 4.4792e-04 - accuracy: 1.0000 - val_loss: 0.3271 - val_accuracy: 0.9400
# Epoch 259/300
# 313/313 [==============================] - 5s 16ms/step - loss: 4.4989e-04 - accuracy: 1.0000 - val_loss: 0.3207 - val_accuracy: 0.9440
# Epoch 260/300
# 313/313 [==============================] - 5s 15ms/step - loss: 0.0712 - accuracy: 0.9855 - val_loss: 0.7736 - val_accuracy: 0.8700
# Epoch 261/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.1080 - accuracy: 0.9694 - val_loss: 0.4571 - val_accuracy: 0.9200
# Epoch 262/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0270 - accuracy: 0.9903 - val_loss: 0.5621 - val_accuracy: 0.9110
# Epoch 263/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0089 - accuracy: 0.9972 - val_loss: 0.4748 - val_accuracy: 0.9210
# Epoch 264/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0078 - accuracy: 0.9978 - val_loss: 0.4110 - val_accuracy: 0.9280
# Epoch 265/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0590 - accuracy: 0.9812 - val_loss: 0.4847 - val_accuracy: 0.9190
# Epoch 266/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0174 - accuracy: 0.9947 - val_loss: 0.4993 - val_accuracy: 0.9160
# Epoch 267/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0595 - accuracy: 0.9828 - val_loss: 0.4225 - val_accuracy: 0.9260
# Epoch 268/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0124 - accuracy: 0.9960 - val_loss: 0.4057 - val_accuracy: 0.9350
# Epoch 269/300
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3706 - val_accuracy: 0.9410
# Epoch 270/300
# 313/313 [==============================] - 6s 18ms/step - loss: 7.1342e-04 - accuracy: 1.0000 - val_loss: 0.3797 - val_accuracy: 0.9450
# Epoch 271/300
# 313/313 [==============================] - 4s 14ms/step - loss: 5.5921e-04 - accuracy: 1.0000 - val_loss: 0.3753 - val_accuracy: 0.9430
# Epoch 272/300
# 313/313 [==============================] - 5s 16ms/step - loss: 4.9601e-04 - accuracy: 1.0000 - val_loss: 0.3775 - val_accuracy: 0.9440
# Epoch 273/300
# 313/313 [==============================] - 5s 17ms/step - loss: 4.3693e-04 - accuracy: 1.0000 - val_loss: 0.3655 - val_accuracy: 0.9460
# Epoch 274/300
# 313/313 [==============================] - 6s 18ms/step - loss: 3.9174e-04 - accuracy: 1.0000 - val_loss: 0.3722 - val_accuracy: 0.9440
# Epoch 275/300
# 313/313 [==============================] - 4s 14ms/step - loss: 3.3011e-04 - accuracy: 1.0000 - val_loss: 0.3678 - val_accuracy: 0.9460
# Epoch 276/300
# 313/313 [==============================] - 5s 16ms/step - loss: 2.8237e-04 - accuracy: 1.0000 - val_loss: 0.3729 - val_accuracy: 0.9490
# Epoch 277/300
# 313/313 [==============================] - 5s 15ms/step - loss: 2.6170e-04 - accuracy: 1.0000 - val_loss: 0.3703 - val_accuracy: 0.9430
# Epoch 278/300
# 313/313 [==============================] - 4s 14ms/step - loss: 2.6782e-04 - accuracy: 1.0000 - val_loss: 0.3885 - val_accuracy: 0.9460
# Epoch 279/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.1488 - accuracy: 0.9676 - val_loss: 0.5011 - val_accuracy: 0.9130
# Epoch 280/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0334 - accuracy: 0.9889 - val_loss: 0.3230 - val_accuracy: 0.9320
# Epoch 281/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0117 - accuracy: 0.9966 - val_loss: 0.4197 - val_accuracy: 0.9290
# Epoch 282/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0179 - accuracy: 0.9937 - val_loss: 0.4594 - val_accuracy: 0.9200
# Epoch 283/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0370 - accuracy: 0.9876 - val_loss: 0.4497 - val_accuracy: 0.9160
# Epoch 284/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0330 - accuracy: 0.9904 - val_loss: 0.4982 - val_accuracy: 0.9080
# Epoch 285/300
# 313/313 [==============================] - 5s 17ms/step - loss: 0.0129 - accuracy: 0.9959 - val_loss: 0.4281 - val_accuracy: 0.9220
# Epoch 286/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0043 - accuracy: 0.9991 - val_loss: 0.4351 - val_accuracy: 0.9330
# Epoch 287/300
# 313/313 [==============================] - 6s 19ms/step - loss: 0.0571 - accuracy: 0.9837 - val_loss: 0.5325 - val_accuracy: 0.9240
# Epoch 288/300
# 313/313 [==============================] - 5s 14ms/step - loss: 0.0206 - accuracy: 0.9937 - val_loss: 0.3805 - val_accuracy: 0.9380
# Epoch 289/300
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.3516 - val_accuracy: 0.9470
# Epoch 290/300
# 313/313 [==============================] - 5s 16ms/step - loss: 7.4368e-04 - accuracy: 1.0000 - val_loss: 0.3540 - val_accuracy: 0.9450
# Epoch 291/300
# 313/313 [==============================] - 4s 14ms/step - loss: 5.2358e-04 - accuracy: 1.0000 - val_loss: 0.3566 - val_accuracy: 0.9470
# Epoch 292/300
# 313/313 [==============================] - 6s 18ms/step - loss: 4.4011e-04 - accuracy: 1.0000 - val_loss: 0.3605 - val_accuracy: 0.9470
# Epoch 293/300
# 313/313 [==============================] - 4s 14ms/step - loss: 3.7110e-04 - accuracy: 1.0000 - val_loss: 0.3599 - val_accuracy: 0.9460
# Epoch 294/300
# 313/313 [==============================] - 5s 16ms/step - loss: 3.0950e-04 - accuracy: 1.0000 - val_loss: 0.3636 - val_accuracy: 0.9490
# Epoch 295/300
# 313/313 [==============================] - 4s 14ms/step - loss: 2.7789e-04 - accuracy: 1.0000 - val_loss: 0.3582 - val_accuracy: 0.9470
# Epoch 296/300
# 313/313 [==============================] - 6s 19ms/step - loss: 2.5275e-04 - accuracy: 1.0000 - val_loss: 0.3603 - val_accuracy: 0.9490
# Epoch 297/300
# 313/313 [==============================] - 4s 14ms/step - loss: 2.2139e-04 - accuracy: 1.0000 - val_loss: 0.3700 - val_accuracy: 0.9450
# Epoch 298/300
# 313/313 [==============================] - 4s 14ms/step - loss: 2.0380e-04 - accuracy: 1.0000 - val_loss: 0.3622 - val_accuracy: 0.9450
# Epoch 299/300
# 313/313 [==============================] - 5s 16ms/step - loss: 1.9429e-04 - accuracy: 1.0000 - val_loss: 0.3567 - val_accuracy: 0.9480
# Epoch 300/300
# 313/313 [==============================] - 6s 18ms/step - loss: 0.0300 - accuracy: 0.9954 - val_loss: 1.6898 - val_accuracy: 0.7780

# %% [markdown]
# # Create plot_loss_curve function

# %%
def plot_loss_curves(history):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  plt.figure(figsize=(12,6))
  # Plot loss
  plt.subplot(1,2,1)
  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.legend()

  # Plot accuracy
  plt.subplot(1,2,2)
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend()

# %% [markdown]
# # Plot the model

# %%
plot_loss_curves(history)

# %% [markdown]
# ## Evaluate model

# %%
model.evaluate(test_data)
# Out:
# 32/32 [==============================] - 1s 34ms/step - loss: 1.6898 - accuracy: 0.7780
# [1.6898481845855713, 0.777999997138977]

# %% [markdown]
# # Evaluate best model

# %% [markdown]
# ## Load the best weight

# %%
model.load_weights(checkpoint_path)

# %% [markdown]
# ### Evaluate

# %%
model.evaluate(train_data), model.evaluate(test_data)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 6.6805e-04 - accuracy: 0.9999
# 32/32 [==============================] - 1s 34ms/step - loss: 0.3342 - accuracy: 0.9500
# ([0.0006680508377030492, 0.9998999834060669],
#  [0.3342253863811493, 0.949999988079071])

# %% [markdown]
# # Load pretrain model

# %% [markdown]
# ## Download pre train model

# %%
! wget "https://github.com/Mahfuzpust/Tomato-Leaf-diseaes/raw/main/pretrain_model.h5"
# Out:
# --2023-12-04 04:03:50--  https://github.com/Mahfuzpust/Tomato-Leaf-diseaes/raw/main/pretrain_model.h5
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Mahfuzpust/Tomato-Leaf-diseaes/main/pretrain_model.h5 [following]
# --2023-12-04 04:03:50--  https://raw.githubusercontent.com/Mahfuzpust/Tomato-Leaf-diseaes/main/pretrain_model.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 173280 (169K) [application/octet-stream]
# Saving to: ‘pretrain_model.h5’
#
# pretrain_model.h5   100%[===================>] 169.22K  --.-KB/s    in 0.03s
#
# 2023-12-04 04:03:50 (5.13 MB/s) - ‘pretrain_model.h5’ saved [173280/173280]

# %% [markdown]
# # Laod model

# %%
load_model = tf.keras.models.load_model("pretrain_model.h5")

# %% [markdown]
# # Summary load_model

# %%
load_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  data_augmentation (Sequent  (None, None, None, 3)     0
#  ial)
#
#  conv2d (Conv2D)             (None, None, None, 32)    896
#
#  max_pooling2d (MaxPooling2  (None, None, None, 32)    0
#  D)
#
#  conv2d_1 (Conv2D)           (None, None, None, 16)    4624
#
#  max_pooling2d_1 (MaxPoolin  (None, None, None, 16)    0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, None, None, 32)    4640
#
#  max_pooling2d_2 (MaxPoolin  (None, None, None, 32)    0
#  g2D)
#
#  global_average_pooling2d (  (None, 32)                0
#  GlobalAveragePooling2D)
#
#  output_layers (Dense)       (None, 10)                330
#
# =================================================================
# Total params: 10490 (40.98 KB)
# Trainable params: 10490 (40.98 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Evaluate load model with valid data or test_data

# %%
load_model.evaluate(train_data),load_model.evaluate(test_data)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0318 - accuracy: 0.9905
# 32/32 [==============================] - 2s 51ms/step - loss: 0.0776 - accuracy: 0.9820
# ([0.03175169602036476, 0.9904999732971191],
#  [0.07763724029064178, 0.9819999933242798])

# %% [markdown]
# # Prediction && visualize

# %%
plt.figure(figsize=(18,12))
for image_batch,label_batch in test_data.take(1):
    predictions = load_model.predict(image_batch)
    predictions = np.argmax(predictions, axis=-1)
    for i in range(0,len(predictions) if len(predictions)<12 else 12):
        plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint32"))
        true_class = class_names[np.argmax(label_batch[i])]
        predict_class = class_names[predictions[i]]
        title = f"""True: {true_class}\n Predict: {predict_class}"""
        plt.title(title, color='g' if true_class==predict_class else 'r')
        plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 170ms/step

# %% [markdown]
# # Confusion matrix

# %%
import itertools
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix

# Our function needs a different name to sklearn's plot_confusion_matrix
def make_confusion_matrix(y_true, y_pred, classes=None, figsize=(10, 10), text_size=15, norm=False):

  # Create the confustion matrix
  cm = confusion_matrix(y_true, y_pred)
  cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis] # normalize it
  n_classes = cm.shape[0] # find the number of classes we're dealing with
  # Plot the figure and make it pretty
  fig, ax = plt.subplots(figsize=figsize)
  cax = ax.matshow(cm, cmap=plt.cm.Blues) # colors will represent how 'correct' a class is, darker == better
  fig.colorbar(cax)

  # Are there a list of classes?
  if classes:
    labels = classes
  else:
    labels = np.arange(cm.shape[0])

  # Label the axes
  ax.set(title="Confusion Matrix",
         xlabel="Predicted label",
         ylabel="True label",
         xticks=np.arange(n_classes), # create enough axis slots for each class
         yticks=np.arange(n_classes),
         xticklabels=labels, # axes will labeled with class names (if they exist) or ints
         yticklabels=labels,
         )

  # Make x-axis labels appear on bottom
  ax.tick_params(axis='x', labelrotation=90)
  ax.xaxis.set_label_position("bottom")
  ax.xaxis.tick_bottom()

  # Set the threshold for different colors
  threshold = (cm.max() + cm.min()) / 2.

  # Plot the text on each cell
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    if norm:
      plt.text(j, i, f"{cm[i, j]} ({cm_norm[i, j]*100:.1f}%)",
              horizontalalignment="center",
              color="white" if cm[i, j] > threshold else "black",
              size=text_size)
    else:
      plt.text(j, i, f"{cm[i, j]}",
              horizontalalignment="center",
              color="white" if cm[i, j] > threshold else "black",
              size=text_size)

# %% [markdown]
# ## Predict y_pred and get y_true

# %%
y_true = np.array([])
y_pred = np.array([])
for x, y in test_data:
    y_true = np.concatenate([y_true, np.argmax(y, axis=-1)], axis=0)
    y_pred = np.concatenate([y_pred, np.argmax(load_model.predict(x), axis=-1)], axis=0)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 77ms/step

# %% [markdown]
# # Plot confusion matrix

# %%
make_confusion_matrix(y_true, y_pred, class_names)
